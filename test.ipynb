# %%
import numpy as np
from skimage import io
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import glob
import os
from skimage.exposure import histogram
from matplotlib.pyplot import bar
from skimage.color import rgb2gray, rgb2hsv

# Convolution:
from scipy.signal import convolve2d
from scipy import fftpack
import math

from skimage.util import random_noise
from skimage.filters import median, threshold_otsu
from skimage.feature import canny

from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# Edges
from skimage.filters import sobel_h, sobel, sobel_v, roberts, prewitt


from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.cluster import MiniBatchKMeans
import pickle
from sklearn import svm
# DataSetPATH = "../input/fonts-dataset-cmp/fonts-dataset" # for kaggle
DataSetPATH = "./Dataset" # for local

# %%
correct=0
SVM_MODEL = pickle.load(open('sift_classifier.pkl', 'rb'))
labels_predicted=[]
for i,test in tqdm(enumerate(X_test)):
      hist=sift(img)
      label=SVM_MODEL.predict([hist])
      labels_predicted.append(label)
      if(label==y_test[i]):
            correct+=1

print(correct/len(X_test)*100)



actual = np.random.binomial(1,.9,size = 1000)
predicted = np.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(y_test, labels_predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1,2,3])

cm_display.plot()
plt.show()
# Out:
# Corrected/Marhey\0.jpeg
# Corrected/Marhey\1.jpeg
# Corrected/Marhey\10.jpeg
# Corrected/Marhey\100.jpeg
# Corrected/Marhey\101.jpeg
# Corrected/Marhey\102.jpeg
# Corrected/Marhey\103.jpeg
# Corrected/Marhey\104.jpeg
# Corrected/Marhey\105.jpeg
# Corrected/Marhey\106.jpeg
# Corrected/Marhey\107.jpeg
# Corrected/Marhey\108.jpeg
# Corrected/Marhey\109.jpeg
# Corrected/Marhey\11.jpeg
# Corrected/Marhey\110.jpeg
# Corrected/Marhey\111.jpeg
# Corrected/Marhey\112.jpeg
# Corrected/Marhey\113.jpeg
# Corrected/Marhey\114.jpeg
# Corrected/Marhey\115.jpeg
# Corrected/Marhey\116.jpeg
# Corrected/Marhey\117.jpeg
# Corrected/Marhey\118.jpeg
# Corrected/Marhey\119.jpeg
# Corrected/Marhey\12.jpeg
# Corrected/Marhey\120.jpeg
# Corrected/Marhey\121.jpeg
# Corrected/Marhey\122.jpeg
# Corrected/Marhey\123.jpeg
# Corrected/Marhey\124.jpeg
# Corrected/Marhey\125.jpeg
# Corrected/Marhey\126.jpeg
# Corrected/Marhey\127.jpeg
# Corrected/Marhey\128.jpeg
# Corrected/Marhey\129.jpeg
# Corrected/Marhey\13.jpeg
# Corrected/Marhey\130.jpeg
# Corrected/Marhey\131.jpeg
# Corrected/Marhey\132.jpeg
# Corrected/Marhey\133.jpeg
# Corrected/Marhey\134.jpeg
# Corrected/Marhey\135.jpeg
# Corrected/Marhey\136.jpeg
# Corrected/Marhey\137.jpeg
# Corrected/Marhey\138.jpeg
# Corrected/Marhey\139.jpeg
# Corrected/Marhey\14.jpeg
# Corrected/Marhey\140.jpeg
# Corrected/Marhey\141.jpeg
# Corrected/Marhey\142.jpeg
# Corrected/Marhey\143.jpeg
# Corrected/Marhey\212.jpeg
# Corrected/Marhey\213.jpeg
# Corrected/Marhey\214.jpeg
# Corrected/Marhey\215.jpeg
# Corrected/Marhey\216.jpeg
# Corrected/Marhey\217.jpeg
# Corrected/Marhey\218.jpeg
# Corrected/Marhey\219.jpeg
# Corrected/Marhey\22.jpeg
# Corrected/Marhey\220.jpeg
# Corrected/Marhey\221.jpeg
# Corrected/Marhey\222.jpeg
# Corrected/Marhey\223.jpeg
# Corrected/Marhey\224.jpeg
# Corrected/Marhey\225.jpeg
# Corrected/Marhey\226.jpeg
# Corrected/Marhey\227.jpeg
# Corrected/Marhey\228.jpeg
# Corrected/Marhey\229.jpeg
# Corrected/Marhey\23.jpeg
# Corrected/Marhey\230.jpeg
# Corrected/Marhey\231.jpeg
# Corrected/Marhey\232.jpeg
# Corrected/Marhey\233.jpeg
# Corrected/Marhey\234.jpeg
# Corrected/Marhey\235.jpeg
# Corrected/Marhey\236.jpeg
# Corrected/Marhey\237.jpeg
# Corrected/Marhey\238.jpeg
# Corrected/Marhey\239.jpeg
# Corrected/Marhey\24.jpeg
# Corrected/Marhey\240.jpeg
# Corrected/Marhey\241.jpeg
# Corrected/Marhey\242.jpeg
# Corrected/Marhey\243.jpeg
# Corrected/Marhey\244.jpeg
# Corrected/Marhey\245.jpeg
# Corrected/Marhey\246.jpeg
# Corrected/Marhey\247.jpeg
# Corrected/Marhey\248.jpeg
# Corrected/Marhey\249.jpeg
# Corrected/Marhey\25.jpeg
# Corrected/Marhey\250.jpeg
# Corrected/Marhey\251.jpeg
# Corrected/Marhey\252.jpeg
# Corrected/Marhey\253.jpeg
# Corrected/Marhey\254.jpeg
# Corrected/Marhey\255.jpeg
# Corrected/Marhey\256.jpeg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 23
#      19                 for d in des:
#      20                     dico.append(d)
# ---> 23 load_dataset()
#
# Cell In[2], line 17, in load_dataset()
#      15 img = cv2.imread(img_path)
#      16 # cv2.imshow('',img)
# ---> 17 kp, des = sift.detectAndCompute(img, None)
#      18 if(des is not None):
#      19     for d in des:
#
# KeyboardInterrupt:

# %%
correct=0
SVM_MODEL = pickle.load(open('sift_classifier.pkl', 'rb'))
labels_predicted=[]
for i,test in tqdm(enumerate(X_test)):
      hist=sift(img)
      label=SVM_MODEL.predict([hist])
      labels_predicted.append(label)
      if(label==y_test[i]):
            correct+=1

print(correct/len(X_test)*100)



actual = np.random.binomial(1,.9,size = 1000)
predicted = np.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(y_test, labels_predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1,2,3])

cm_display.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 SVM_MODEL = pickle.load(open('sift_classifier.pkl', 'rb'))
#       3 labels_predicted=[]
# ----> 4 for i,test in tqdm(enumerate(X_test)):
#       5       hist=sift(img)
#       6       label=SVM_MODEL.predict([hist])
#
# NameError: name 'tqdm' is not defined
